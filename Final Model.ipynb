# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../input/simple-datasets/Training Data.csv')
df.head()
# Out:
#    Id   income  age  experience  married house_ownership car_ownership  \
# 0   1  1303835   23           3   single          rented            no
# 1   2  7574516   40          10   single          rented            no
# 2   3  3991815   66           4  married          rented            no
# 3   4  6256451   41           2   single          rented           yes
# 4   5  5768871   47          11   single          rented            no
#
#             profession                 city           state  \
# 0  Mechanical_engineer                 Rewa  Madhya_Pradesh
# 1   Software_Developer             Parbhani     Maharashtra
# 2     Technical_writer            Alappuzha          Kerala
# 3   Software_Developer          Bhubaneswar          Odisha
# 4        Civil_servant  Tiruchirappalli[10]      Tamil_Nadu
#
#    current_job_years  current_house_years  risk_flag
# 0                  3                   13          0
# 1                  9                   13          0
# ...

# %%
df.corr()
# Out:
#                            Id    income       age  experience  \
# Id                   1.000000 -0.001324 -0.001816   -0.005810
# income              -0.001324  1.000000 -0.000652    0.006422
# age                 -0.001816 -0.000652  1.000000   -0.001118
# experience          -0.005810  0.006422 -0.001118    1.000000
# current_job_years   -0.003250  0.007045  0.002154    0.646098
# current_house_years  0.001972 -0.002397 -0.020134    0.019309
# risk_flag            0.032153 -0.003091 -0.021809   -0.034523
#
#                      current_job_years  current_house_years  risk_flag
# Id                           -0.003250             0.001972   0.032153
# income                        0.007045            -0.002397  -0.003091
# age                           0.002154            -0.020134  -0.021809
# experience                    0.646098             0.019309  -0.034523
# current_job_years             1.000000             0.005372  -0.016942
# ...

# %%
df.isnull().sum()
# Out:
# Id                     0
# income                 0
# age                    0
# experience             0
# married                0
# house_ownership        0
# car_ownership          0
# profession             0
# city                   0
# state                  0
# current_job_years      0
# current_house_years    0
# risk_flag              0
# dtype: int64

# %%
df['married'].unique()
# Out:
# array(['single', 'married'], dtype=object)

# %%
df['house_ownership'].unique()
# Out:
# array(['rented', 'norent_noown', 'owned'], dtype=object)

# %%
df['car_ownership'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['profession'].unique()
# Out:
# array(['Mechanical_engineer', 'Software_Developer', 'Technical_writer',
#        'Civil_servant', 'Librarian', 'Economist', 'Flight_attendant',
#        'Architect', 'Designer', 'Physician', 'Financial_Analyst',
#        'Air_traffic_controller', 'Politician', 'Police_officer', 'Artist',
#        'Surveyor', 'Design_Engineer', 'Chemical_engineer',
#        'Hotel_Manager', 'Dentist', 'Comedian', 'Biomedical_Engineer',
#        'Graphic_Designer', 'Computer_hardware_engineer',
#        'Petroleum_Engineer', 'Secretary', 'Computer_operator',
#        'Chartered_Accountant', 'Technician', 'Microbiologist',
#        'Fashion_Designer', 'Aviator', 'Psychologist', 'Magistrate',
#        'Lawyer', 'Firefighter', 'Engineer', 'Official', 'Analyst',
#        'Geologist', 'Drafter', 'Statistician', 'Web_designer',
#        'Consultant', 'Chef', 'Army_officer', 'Surgeon', 'Scientist',
#        'Civil_engineer', 'Industrial_Engineer', 'Technology_specialist'],
#       dtype=object)

# %%
df['state'].unique()
# Out:
# array(['Madhya_Pradesh', 'Maharashtra', 'Kerala', 'Odisha', 'Tamil_Nadu',
#        'Gujarat', 'Rajasthan', 'Telangana', 'Bihar', 'Andhra_Pradesh',
#        'West_Bengal', 'Haryana', 'Puducherry', 'Karnataka',
#        'Uttar_Pradesh', 'Himachal_Pradesh', 'Punjab', 'Tripura',
#        'Uttarakhand', 'Jharkhand', 'Mizoram', 'Assam',
#        'Jammu_and_Kashmir', 'Delhi', 'Chhattisgarh', 'Chandigarh',
#        'Uttar_Pradesh[5]', 'Manipur', 'Sikkim'], dtype=object)

# %%
df['city'].unique()
# Out:
# array(['Rewa', 'Parbhani', 'Alappuzha', 'Bhubaneswar',
#        'Tiruchirappalli[10]', 'Jalgaon', 'Tiruppur', 'Jamnagar',
#        'Kota[6]', 'Karimnagar', 'Hajipur[31]', 'Adoni', 'Erode[17]',
#        'Kollam', 'Madurai', 'Anantapuram[24]', 'Kamarhati', 'Bhusawal',
#        'Sirsa', 'Amaravati', 'Secunderabad', 'Ahmedabad', 'Ajmer',
#        'Ongole', 'Miryalaguda', 'Ambattur', 'Indore', 'Pondicherry',
#        'Shimoga', 'Chennai', 'Gulbarga', 'Khammam', 'Saharanpur',
#        'Gopalpur', 'Amravati', 'Udupi', 'Howrah', 'Aurangabad[39]',
#        'Hospet', 'Shimla', 'Khandwa', 'Bidhannagar', 'Bellary', 'Danapur',
#        'Purnia[26]', 'Bijapur', 'Patiala', 'Malda', 'Sagar', 'Durgapur',
#        'Junagadh', 'Singrauli', 'Agartala', 'Thanjavur', 'Hindupur',
#        'Naihati', 'North_Dumdum', 'Panchkula', 'Anantapur', 'Serampore',
#        'Bathinda', 'Nadiad', 'Kanpur', 'Haridwar', 'Berhampur',
#        'Jamshedpur', 'Hyderabad', 'Bidar', 'Kottayam', 'Solapur',
# ...

# %%
for x in range(len(df['state'])):
    if df['state'][x] == 'Uttar_Pradesh[5]':
        df['state'][x] = 'Uttar_Pradesh'
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df['state'].unique()
# Out:
# array(['Madhya_Pradesh', 'Maharashtra', 'Kerala', 'Odisha', 'Tamil_Nadu',
#        'Gujarat', 'Rajasthan', 'Telangana', 'Bihar', 'Andhra_Pradesh',
#        'West_Bengal', 'Haryana', 'Puducherry', 'Karnataka',
#        'Uttar_Pradesh', 'Himachal_Pradesh', 'Punjab', 'Tripura',
#        'Uttarakhand', 'Jharkhand', 'Mizoram', 'Assam',
#        'Jammu_and_Kashmir', 'Delhi', 'Chhattisgarh', 'Chandigarh',
#        'Manipur', 'Sikkim'], dtype=object)

# %%
for i in range(len(df['city'])):
    if df['city'][i].find('[') >= 0:
        df['city'][i] = df['city'][i].split('[')[0]
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df['city'].unique()
# Out:
# array(['Rewa', 'Parbhani', 'Alappuzha', 'Bhubaneswar', 'Tiruchirappalli',
#        'Jalgaon', 'Tiruppur', 'Jamnagar', 'Kota', 'Karimnagar', 'Hajipur',
#        'Adoni', 'Erode', 'Kollam', 'Madurai', 'Anantapuram', 'Kamarhati',
#        'Bhusawal', 'Sirsa', 'Amaravati', 'Secunderabad', 'Ahmedabad',
#        'Ajmer', 'Ongole', 'Miryalaguda', 'Ambattur', 'Indore',
#        'Pondicherry', 'Shimoga', 'Chennai', 'Gulbarga', 'Khammam',
#        'Saharanpur', 'Gopalpur', 'Amravati', 'Udupi', 'Howrah',
#        'Aurangabad', 'Hospet', 'Shimla', 'Khandwa', 'Bidhannagar',
#        'Bellary', 'Danapur', 'Purnia', 'Bijapur', 'Patiala', 'Malda',
#        'Sagar', 'Durgapur', 'Junagadh', 'Singrauli', 'Agartala',
#        'Thanjavur', 'Hindupur', 'Naihati', 'North_Dumdum', 'Panchkula',
#        'Anantapur', 'Serampore', 'Bathinda', 'Nadiad', 'Kanpur',
#        'Haridwar', 'Berhampur', 'Jamshedpur', 'Hyderabad', 'Bidar',
#        'Kottayam', 'Solapur', 'Suryapet', 'Aizawl', 'Asansol', 'Deoghar',
# ...

# %%
a = df.iloc[:, 4:10]
for col in a.columns:
    print(col, ' : ', len(a[col].unique()), ' labels')
# Out:
# married  :  2  labels
# house_ownership  :  3  labels
# car_ownership  :  2  labels
# profession  :  51  labels
# city  :  316  labels
# state  :  28  labels

# %%
#data = pd.get_dummies(df.iloc[:, [4]], drop_first=True)

marry = {'single' : 0, 'married' : 1}
marry
# Out:
# {'single': 0, 'married': 1}

# %%
df['marry'] = df['married'].map(marry)

# %%
house_owner = {'rented' : 1, 'norent_noown' : 0, 'owned' : 2}
house_owner
# Out:
# {'rented': 1, 'norent_noown': 0, 'owned': 2}

# %%
df['house_owners'] = df['house_ownership'].map(house_owner)

# %%
car_owner = {'no' : 0, 'yes' : 1}
car_owner
# Out:
# {'no': 0, 'yes': 1}

# %%
df['car_owners'] = df['car_ownership'].map(car_owner)

# %%
df.head()
# Out:
#    Id   income  age  experience  married house_ownership car_ownership  \
# 0   1  1303835   23           3   single          rented            no
# 1   2  7574516   40          10   single          rented            no
# 2   3  3991815   66           4  married          rented            no
# 3   4  6256451   41           2   single          rented           yes
# 4   5  5768871   47          11   single          rented            no
#
#             profession             city           state  current_job_years  \
# 0  Mechanical_engineer             Rewa  Madhya_Pradesh                  3
# 1   Software_Developer         Parbhani     Maharashtra                  9
# 2     Technical_writer        Alappuzha          Kerala                  4
# 3   Software_Developer      Bhubaneswar          Odisha                  2
# 4        Civil_servant  Tiruchirappalli      Tamil_Nadu                  3
#
#    current_house_years  risk_flag  marry  house_owners  car_owners
# ...

# %%
df.drop(df.iloc[:, 4:7], axis = 1, inplace = True)
df.head()
# Out:
#    Id   income  age  experience           profession             city  \
# 0   1  1303835   23           3  Mechanical_engineer             Rewa
# 1   2  7574516   40          10   Software_Developer         Parbhani
# 2   3  3991815   66           4     Technical_writer        Alappuzha
# 3   4  6256451   41           2   Software_Developer      Bhubaneswar
# 4   5  5768871   47          11        Civil_servant  Tiruchirappalli
#
#             state  current_job_years  current_house_years  risk_flag  marry  \
# 0  Madhya_Pradesh                  3                   13          0      0
# 1     Maharashtra                  9                   13          0      0
# 2          Kerala                  4                   10          0      1
# 3          Odisha                  2                   12          1      0
# 4      Tamil_Nadu                  3                   14          1      0
#
#    house_owners  car_owners
# 0             1           0
# 1             1           0
# ...

# %%
df['profession'].value_counts().sort_values(ascending = False).head(50)
# Out:
# Physician                     5957
# Statistician                  5806
# Web_designer                  5397
# Psychologist                  5390
# Computer_hardware_engineer    5372
# Drafter                       5359
# Magistrate                    5357
# Fashion_Designer              5304
# Air_traffic_controller        5281
# Comedian                      5259
# Industrial_Engineer           5250
# Mechanical_engineer           5217
# Chemical_engineer             5205
# Technical_writer              5195
# Hotel_Manager                 5178
# Financial_Analyst             5167
# Graphic_Designer              5166
# Flight_attendant              5128
# Biomedical_Engineer           5127
# Secretary                     5061
# Software_Developer            5053
# Petroleum_Engineer            5041
# Police_officer                5035
# Computer_operator             4990
# Politician                    4944
# Microbiologist                4881
# Technician                    4864
# ...

# %%
mean_ordinal = df.groupby(['city'])['risk_flag'].mean().to_dict()

# %%
mean_ordinal
# Out:
# {'Adoni': 0.1080797481636936,
#  'Agartala': 0.1681087762669963,
#  'Agra': 0.0800395256916996,
#  'Ahmedabad': 0.2049306625577812,
#  'Ahmednagar': 0.05891472868217054,
#  'Aizawl': 0.11071849234393404,
#  'Ajmer': 0.13872135102533173,
#  'Akola': 0.08865710560625815,
#  'Alappuzha': 0.1308139534883721,
#  'Aligarh': 0.12121212121212122,
#  'Allahabad': 0.13055181695827725,
#  'Alwar': 0.13114754098360656,
#  'Amaravati': 0.06428571428571428,
#  'Ambala': 0.15206185567010308,
#  'Ambarnath': 0.12117780294450736,
#  'Ambattur': 0.12030075187969924,
#  'Amravati': 0.1618421052631579,
#  'Amritsar': 0.06438356164383562,
#  'Amroha': 0.06666666666666667,
#  'Anand': 0.10375275938189846,
#  'Anantapur': 0.08290155440414508,
#  'Anantapuram': 0.08350100603621731,
#  'Arrah': 0.0625,
#  'Asansol': 0.1050228310502283,
#  'Aurangabad': 0.0881399870382372,
#  'Avadi': 0.14392803598200898,
#  'Bahraich': 0.1422680412371134,
#  'Ballia': 0.10602409638554217,
#  'Bally': 0.07048458149779736,
# ...

# %%
df['city_encoded'] = df['city'].map(mean_ordinal)

# %%
df.head()
# Out:
#    Id   income  age  experience           profession             city  \
# 0   1  1303835   23           3  Mechanical_engineer             Rewa
# 1   2  7574516   40          10   Software_Developer         Parbhani
# 2   3  3991815   66           4     Technical_writer        Alappuzha
# 3   4  6256451   41           2   Software_Developer      Bhubaneswar
# 4   5  5768871   47          11        Civil_servant  Tiruchirappalli
#
#             state  current_job_years  current_house_years  risk_flag  marry  \
# 0  Madhya_Pradesh                  3                   13          0      0
# 1     Maharashtra                  9                   13          0      0
# 2          Kerala                  4                   10          0      1
# 3          Odisha                  2                   12          1      0
# 4      Tamil_Nadu                  3                   14          1      0
#
#    house_owners  car_owners  city_encoded
# 0             1           0      0.121554
# ...

# %%
mean_ordinal_state = df.groupby(['state'])['risk_flag'].mean().to_dict()
mean_ordinal_state
# Out:
# {'Andhra_Pradesh': 0.11602166264774479,
#  'Assam': 0.13169073916737467,
#  'Bihar': 0.13058645096056623,
#  'Chandigarh': 0.09298780487804878,
#  'Chhattisgarh': 0.1332811684924361,
#  'Delhi': 0.10455373406193079,
#  'Gujarat': 0.11772440392706872,
#  'Haryana': 0.12420785804816223,
#  'Himachal_Pradesh': 0.1332533013205282,
#  'Jammu_and_Kashmir': 0.15898876404494383,
#  'Jharkhand': 0.13329615170105968,
#  'Karnataka': 0.10029523407844791,
#  'Kerala': 0.16709732988802756,
#  'Madhya_Pradesh': 0.15436906953689278,
#  'Maharashtra': 0.11325404897895314,
#  'Manipur': 0.21554770318021202,
#  'Mizoram': 0.11071849234393404,
#  'Odisha': 0.14255045083726922,
#  'Puducherry': 0.11653872993719469,
#  'Punjab': 0.09004237288135593,
#  'Rajasthan': 0.1408327883148027,
#  'Sikkim': 0.046052631578947366,
#  'Tamil_Nadu': 0.10316260506742456,
#  'Telangana': 0.1301169590643275,
#  'Tripura': 0.1681087762669963,
#  'Uttar_Pradesh': 0.11803863706550458,
#  'Uttarakhand': 0.07097118463180363,
# ...

# %%
df['state_encoded'] = df['state'].map(mean_ordinal_state)

# %%
df.head()
# Out:
#    Id   income  age  experience           profession             city  \
# 0   1  1303835   23           3  Mechanical_engineer             Rewa
# 1   2  7574516   40          10   Software_Developer         Parbhani
# 2   3  3991815   66           4     Technical_writer        Alappuzha
# 3   4  6256451   41           2   Software_Developer      Bhubaneswar
# 4   5  5768871   47          11        Civil_servant  Tiruchirappalli
#
#             state  current_job_years  current_house_years  risk_flag  marry  \
# 0  Madhya_Pradesh                  3                   13          0      0
# 1     Maharashtra                  9                   13          0      0
# 2          Kerala                  4                   10          0      1
# 3          Odisha                  2                   12          1      0
# 4      Tamil_Nadu                  3                   14          1      0
#
#    house_owners  car_owners  city_encoded  state_encoded
# ...

# %%
mean_ordinal_profession = df.groupby(['profession'])['risk_flag'].mean().to_dict()

mean_ordinal_profession
# Out:
# {'Air_traffic_controller': 0.1353910244271918,
#  'Analyst': 0.12146529562982006,
#  'Architect': 0.13120034356882113,
#  'Army_officer': 0.15211328041192876,
#  'Artist': 0.1226085167660975,
#  'Aviator': 0.13493064312736444,
#  'Biomedical_Engineer': 0.12755997659449972,
#  'Chartered_Accountant': 0.15357222345871355,
#  'Chef': 0.12146709816612729,
#  'Chemical_engineer': 0.11162343900096061,
#  'Civil_engineer': 0.1358318890814558,
#  'Civil_servant': 0.11579424427826875,
#  'Comedian': 0.11960448754516068,
#  'Computer_hardware_engineer': 0.12844378257632166,
#  'Computer_operator': 0.12404809619238477,
#  'Consultant': 0.1252079866888519,
#  'Dentist': 0.109577582601422,
#  'Design_Engineer': 0.1069993656164094,
#  'Designer': 0.10917790343627665,
#  'Drafter': 0.1128941966784848,
#  'Economist': 0.09927837305926088,
#  'Engineer': 0.11808300395256917,
#  'Fashion_Designer': 0.11538461538461539,
#  'Financial_Analyst': 0.10315463518482679,
# ...

# %%
df['profession_encoded'] = df['profession'].map(mean_ordinal_profession)

# %%
df.drop(df.iloc[:, 4:7], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Id   income  age  experience  current_job_years  current_house_years  \
# 0   1  1303835   23           3                  3                   13
# 1   2  7574516   40          10                  9                   13
# 2   3  3991815   66           4                  4                   10
# 3   4  6256451   41           2                  2                   12
# 4   5  5768871   47          11                  3                   14
#
#    risk_flag  marry  house_owners  car_owners  city_encoded  state_encoded  \
# 0          0      0             1           0      0.121554       0.154369
# 1          0      0             1           0      0.122497       0.113254
# 2          0      1             1           0      0.130814       0.167097
# 3          1      0             1           1      0.326194       0.142550
# 4          1      0             1           0      0.121137       0.103163
#
#    profession_encoded
# 0            0.111558
# 1            0.148427
# ...

# %%
cols = list(df.columns.values)
df = df[cols[0:6] + cols[7:13] + [cols[6]]]

# %%
df.head()
# Out:
#    Id   income  age  experience  current_job_years  current_house_years  \
# 0   1  1303835   23           3                  3                   13
# 1   2  7574516   40          10                  9                   13
# 2   3  3991815   66           4                  4                   10
# 3   4  6256451   41           2                  2                   12
# 4   5  5768871   47          11                  3                   14
#
#    marry  house_owners  car_owners  city_encoded  state_encoded  \
# 0      0             1           0      0.121554       0.154369
# 1      0             1           0      0.122497       0.113254
# 2      1             1           0      0.130814       0.167097
# 3      0             1           1      0.326194       0.142550
# 4      0             1           0      0.121137       0.103163
#
#    profession_encoded  risk_flag
# 0            0.111558          0
# 1            0.148427          0
# 2            0.134167          0
# ...

# %%
X_train = df.iloc[:, 1:-1]
y_train = df.iloc[:, [-1]]

# %%
count_class_0, count_class_1 = y_train.value_counts()

# %%
count_class_0, count_class_1
# Out:
# (221004, 30996)

# %%
df_class_0 = df[df['risk_flag'] == 0]
df_class_1 = df[df['risk_flag'] == 1]

# %%
df_class_0_under = df_class_0.sample(count_class_1)

df_train_under = pd.concat([df_class_0_under, df_class_1], axis = 0)
df_train_under.shape
# Out:
# (61992, 13)

# %%
X_train_under = df_train_under.iloc[:, 1:-1]
y_train_under = df_train_under.iloc[:, [-1]]

# %%
X_train_under.shape, y_train_under.shape
# Out:
# ((61992, 11), (61992, 1))

# %%
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_train_over = pd.concat([df_class_1_over, df_class_0], axis = 0)
df_train_over.shape
# Out:
# (442008, 13)

# %%
X_train_over = df_train_over.iloc[:, 1:-1]
y_train_over = df_train_over.iloc[:, [-1]]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled_over = scaler.fit_transform(X_train_over)

pd.DataFrame(X_train_scaled_over)
# Out:
#               0         1         2         3         4        5        6   \
# 0       0.957041  1.654117  1.184662  1.554719  0.007380 -0.32362 -0.07216
# 1       0.419799 -0.205704 -1.464763 -1.425860 -1.421742 -0.32362 -0.07216
# 2      -0.206412 -1.251852 -1.299174 -1.154898 -1.421742 -0.32362 -0.07216
# 3      -1.175272  0.607968 -0.471229 -0.883937  0.721941 -0.32362 -0.07216
# 4       1.416244 -1.251852 -1.299174 -1.154898  0.721941 -0.32362 -0.07216
# ...          ...       ...       ...       ...       ...      ...      ...
# 442003  1.094148 -0.380062  0.522306 -0.071051 -0.707181 -0.32362 -0.07216
# 442004 -0.739674 -1.368091  0.025538 -0.071051 -0.707181 -0.32362 -0.07216
# 442005 -0.160013 -0.205704 -0.471229  0.199910  0.007380 -0.32362 -0.07216
# 442006  0.525232 -0.263823 -1.630352 -1.696822 -1.421742 -0.32362 -0.07216
# 442007  1.410187  1.189162  1.184662  0.199910 -0.707181 -0.32362 -0.07216
#
#               7         8         9         10
# ...

# %% [markdown]
# # Test data

# %%
df_test = pd.read_csv('../input/simple-datasets/Test Data.csv')
df_test.head()
# Out:
#    id   income  age  experience  married house_ownership car_ownership  \
# 0   1  7393090   59          19   single          rented            no
# 1   2  1215004   25           5   single          rented            no
# 2   3  8901342   50          12   single          rented            no
# 3   4  1944421   49           9  married          rented           yes
# 4   5    13429   25          18   single          rented           yes
#
#     profession        city        state  current_job_years  \
# 0    Geologist       Malda  West Bengal                  4
# 1  Firefighter       Jalna  Maharashtra                  5
# 2       Lawyer       Thane  Maharashtra                  9
# 3      Analyst       Latur  Maharashtra                  3
# 4     Comedian  Berhampore  West Bengal                 13
#
#    current_house_years
# 0                   13
# 1                   10
# 2                   14
# 3                   12
# 4                   11

# %%
df_test.isnull().sum()
# Out:
# id                     0
# income                 0
# age                    0
# experience             0
# married                0
# house_ownership        0
# car_ownership          0
# profession             0
# city                   0
# state                  0
# current_job_years      0
# current_house_years    0
# dtype: int64

# %%
for i in range(len(df_test['city'])):
    if df_test['city'][i].find('[') >= 0:
        df_test['city'][i] = df_test['city'][i].split('[')[0]
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_test['city'].unique()
# Out:
# array(['Malda', 'Jalna', 'Thane', 'Latur', 'Berhampore', 'Ramgarh',
#        'Pallavaram', 'Yamunanagar', 'Anand', 'Nandyal', 'Bihar Sharif',
#        'Shivpuri', 'Bhilai', 'Bhavnagar', 'Tiruppur', 'Bongaigaon',
#        'Hapur', 'Bulandshahr', 'Pimpri-Chinchwad', 'Kurnool', 'Kakinada',
#        'Tadepalligudem', 'Bidhannagar', 'Hospet', 'Jamshedpur',
#        'Sri Ganganagar', 'Udaipur', 'Sikar', 'Suryapet', 'Kavali',
#        'Erode', 'Chittoor', 'Gwalior', 'Allahabad', 'Pudukkottai',
#        'Srinagar', 'Jamalpur', 'Fatehpur', 'Coimbatore', 'Berhampur',
#        'Thanjavur', 'Bahraich', 'Deoghar', 'Nagaon', 'Anantapuram',
#        'Gulbarga', 'Visakhapatnam', 'Morbi', 'Tirupati', 'Karnal',
#        'Raichur', 'Haridwar', 'Giridih', 'Nagercoil', 'Rohtak', 'Katni',
#        'Rewa', 'Siliguri', 'Buxar', 'Mangalore', 'Shimoga', 'Guwahati',
#        'Katihar', 'Farrukhabad', 'Etawah', 'Kharagpur', 'Jalandhar',
#        'Khora, Ghaziabad', 'Jammu', 'Aurangabad', 'Pondicherry', 'Durg',
# ...

# %%
len(df_test['state'].unique())
# Out:
# 29

# %%
for i in range(len(df_test['state'])):
    if df_test['state'][i].find('[') >= 0:
        df_test['state'][i] = df_test['state'][i].split('[')[0]
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_test['state'].unique()
# Out:
# array(['West Bengal', 'Maharashtra', 'Jharkhand', 'Tamil Nadu', 'Haryana',
#        'Gujarat', 'Andhra Pradesh', 'Bihar', 'Madhya Pradesh',
#        'Chhattisgarh', 'Assam', 'Uttar Pradesh', 'Karnataka', 'Rajasthan',
#        'Telangana', 'Jammu and Kashmir', 'Odisha', 'Uttarakhand',
#        'Punjab', 'Puducherry', 'Himachal Pradesh', 'Chandigarh',
#        'Mizoram', 'Tripura', 'Delhi', 'Kerala', 'Sikkim', 'Manipur'],
#       dtype=object)

# %%
a = df_test.iloc[:, 4:10]
for col in a.columns:
    print(col, ' : ', len(a[col].unique()), ' labels')
# Out:
# married  :  2  labels
# house_ownership  :  3  labels
# car_ownership  :  2  labels
# profession  :  51  labels
# city  :  316  labels
# state  :  28  labels

# %%
#data = pd.get_dummies(df_test.iloc[:, 4:7], drop_first=True)

# %%
marry = {'single' : 0, 'married' : 1}
marry

# %%
df_test['marry'] = df_test['married'].map(marry)

# %%
df_test['house_owners'] = df_test['house_ownership'].map(house_owner)
df_test['car_owners'] = df_test['car_ownership'].map(car_owner)

# %%
df_test.head()
# Out:
#    id   income  age  experience  married house_ownership car_ownership  \
# 0   1  7393090   59          19   single          rented            no
# 1   2  1215004   25           5   single          rented            no
# 2   3  8901342   50          12   single          rented            no
# 3   4  1944421   49           9  married          rented           yes
# 4   5    13429   25          18   single          rented           yes
#
#     profession        city        state  current_job_years  \
# 0    Geologist       Malda  West Bengal                  4
# 1  Firefighter       Jalna  Maharashtra                  5
# 2       Lawyer       Thane  Maharashtra                  9
# 3      Analyst       Latur  Maharashtra                  3
# 4     Comedian  Berhampore  West Bengal                 13
#
#    current_house_years  marry  house_owners  car_owners
# 0                   13      0             1           0
# 1                   10      0             1           0
# ...

# %%
df_test['state'] = df_test['state'].str.replace(' ', '_')
df_test['city'] = df_test['city'].str.replace(' ', '_')
df_test['profession'] = df_test['profession'].str.replace(' ', '_')
df_test['state'].unique()
# Out:
# array(['West_Bengal', 'Maharashtra', 'Jharkhand', 'Tamil_Nadu', 'Haryana',
#        'Gujarat', 'Andhra_Pradesh', 'Bihar', 'Madhya_Pradesh',
#        'Chhattisgarh', 'Assam', 'Uttar_Pradesh', 'Karnataka', 'Rajasthan',
#        'Telangana', 'Jammu_and_Kashmir', 'Odisha', 'Uttarakhand',
#        'Punjab', 'Puducherry', 'Himachal_Pradesh', 'Chandigarh',
#        'Mizoram', 'Tripura', 'Delhi', 'Kerala', 'Sikkim', 'Manipur'],
#       dtype=object)

# %%
df_test['city_encoded'] = df_test['city'].map(mean_ordinal)
df_test['state_encoded'] = df_test['state'].map(mean_ordinal_state)
df_test['profession_encoded'] = df_test['profession'].map(mean_ordinal_profession)
df_test.head()
# Out:
#    id   income  age  experience  married house_ownership car_ownership  \
# 0   1  7393090   59          19   single          rented            no
# 1   2  1215004   25           5   single          rented            no
# 2   3  8901342   50          12   single          rented            no
# 3   4  1944421   49           9  married          rented           yes
# 4   5    13429   25          18   single          rented           yes
#
#     profession        city        state  current_job_years  \
# 0    Geologist       Malda  West_Bengal                  4
# 1  Firefighter       Jalna  Maharashtra                  5
# 2       Lawyer       Thane  Maharashtra                  9
# 3      Analyst       Latur  Maharashtra                  3
# 4     Comedian  Berhampore  West_Bengal                 13
#
#    current_house_years  marry  house_owners  car_owners  city_encoded  \
# 0                   13      0             1           0      0.112277
# ...

# %%
df_test.drop(df_test.iloc[:, 4:10], axis =1, inplace = True)
df_test.head()
# Out:
#    id   income  age  experience  current_job_years  current_house_years  \
# 0   1  7393090   59          19                  4                   13
# 1   2  1215004   25           5                  5                   10
# 2   3  8901342   50          12                  9                   14
# 3   4  1944421   49           9                  3                   12
# 4   5    13429   25          18                 13                   11
#
#    marry  house_owners  car_owners  city_encoded  state_encoded  \
# 0      0             1           0      0.112277       0.128135
# 1      0             1           0      0.108449       0.113254
# 2      0             1           0      0.072746       0.113254
# 3      1             1           1      0.039655       0.113254
# 4      0             1           1      0.148101       0.128135
#
#    profession_encoded
# 0            0.144264
# 1            0.135789
# 2            0.129514
# 3            0.121465
# 4            0.119604

# %%
ab = df_test.iloc[:, 1:]
X_test = ab.copy()

X_test.shape
# Out:
# (28000, 11)

# %%
y_train = y_train.squeeze()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_test_scaled = scaler.fit_transform(X_test)

pd.DataFrame(X_test_scaled)
# Out:
#              0         1         2         3         4         5         6   \
# 0      0.824999  0.522215  1.473253 -0.641752  0.721323 -0.335314 -0.085132
# 1     -1.331487 -1.462656 -0.849546 -0.367415 -1.425015 -0.335314 -0.085132
# 2      1.351460 -0.003192  0.311854  0.729931  1.436769 -0.335314 -0.085132
# 3     -1.076881 -0.061571 -0.185889 -0.916088  0.005877  2.982280 -0.085132
# 4     -1.750901 -1.462656  1.307339  1.827278 -0.709569 -0.335314 -0.085132
# ...         ...       ...       ...       ...       ...       ...       ...
# 27995  1.719411  0.405458  0.477768 -0.367415 -1.425015 -0.335314 -0.085132
# 27996 -0.737131 -0.178328 -0.185889  0.729931  1.436769 -0.335314 -0.085132
# 27997  1.065610 -1.521035 -0.849546 -0.641752  0.721323 -0.335314 -0.085132
# 27998  1.551411  0.055187  0.477768  1.827278  1.436769 -0.335314 -0.085132
# 27999  1.473283 -0.470221 -0.185889 -0.641752 -1.425015 -0.335314 -0.085132
#
#              7         8         9         10
# ...

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

feature_selection = SelectFromModel(Lasso(alpha = 0.05, random_state=1))
feature_selection.fit(X_train_over, y_train_over)
# Out:
# SelectFromModel(estimator=Lasso(alpha=0.05, random_state=1))

# %%
feature_selection.get_support()
# Out:
# array([False,  True,  True, False, False, False, False, False, False,
#        False, False])

# %%
#from tensorflow import keras
#import tensorflow as tf
#from tensorflow.keras.layers import Dense, LeakyReLU
#from tensorflow.keras.models import Sequential

# %%
#X_train_scaled_over.shape

# %%
#model = Sequential([
#    keras.layers.Dense(256, activation = 'relu', input_shape = (X_train_scaled_over.shape[-1], )),
#    keras.layers.Dense(512, activation = 'relu'),
#    keras.layers.Dropout(0.3),
#    keras.layers.Dense(256, activation = 'relu'),
#    keras.layers.Dropout(0.3),
#    keras.layers.Dense(128, activation = 'relu'),
#    keras.layers.Dropout(0.3),
#    keras.layers.Dense(1, activation = 'sigmoid'),
#])

#model.summary()

# %%
#metrics = [
#    keras.metrics.Precision(name="precision"),
#    keras.metrics.Recall(name="recall"),
#    keras.metrics.AUC(name="auc_score")
#]

#model.compile(
#    optimizer=keras.optimizers.Adam(1e-2), loss="binary_crossentropy", metrics=metrics
#)

#callbacks = [keras.callbacks.ModelCheckpoint("fraud_model_at_epoch_{epoch}.h5")]

#model.fit(
#    X_train_scaled_over,
#    y_train_over,
#    batch_size=2048,
#    epochs=30,
#    verbose=2,
#    callbacks=callbacks,
#)

# %%
#from sklearn.model_selection import RandomizedSearchCV

#n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 3)]
#max_features = ["auto", "sqrt", "log2"]
#max_depth = [int(x) for x in np.linspace(5, 30, num = 3)]
#min_samples_split = [2, 5, 10]
#min_samples_leaf = [2, 5]


#random_grid = {'n_estimators' : n_estimators,
#              'max_features' : max_features,
#              'max_depth' : max_depth,
#              'min_samples_split' : min_samples_split,
#              'min_samples_leaf' : min_samples_leaf}
#print(random_grid)

# %%
#from sklearn.ensemble import RandomForestRegressor
#rf = RandomForestRegressor()

#rf_random = RandomizedSearchCV(estimator = rf, param_distributions=random_grid, scoring='neg_mean_squared_error', n_iter = 10, cv = 4, verbose=4, random_state=42, n_jobs = -1)

# %%
#rf_random.fit(X_train_over, y_train_over)

# %%
import xgboost
classifier=xgboost.XGBClassifier()
from sklearn.model_selection import RandomizedSearchCV

params={
 "learning_rate"    : [0.05, 0.10, 0.15, 0.20, 0.25, 0.30 ] ,
 "max_depth"        : [ 3, 4, 5, 6, 8, 10, 12, 15],
 "min_child_weight" : [ 1, 3, 5, 7 ],
 "gamma"            : [ 0.0, 0.1, 0.2 , 0.3, 0.4 ],
 "colsample_bytree" : [ 0.3, 0.4, 0.5 , 0.7 ],
 "n_estimators"     : [100, 200, 400, 600, 800, 1000] 
}

random_search=RandomizedSearchCV(classifier,param_distributions=params,n_iter=5,scoring='roc_auc',n_jobs=-1,cv=5,verbose=3)
random_search.fit(X_train_over,y_train_over)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...

# %%
random_search.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.4, gamma=0.1, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.3, max_delta_step=0, max_depth=15,
#               min_child_weight=5, missing=nan, monotone_constraints='()',
#               n_estimators=200, n_jobs=4, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
random_search.best_params_
# Out:
# {'n_estimators': 200,
#  'min_child_weight': 5,
#  'max_depth': 15,
#  'learning_rate': 0.3,
#  'gamma': 0.1,
#  'colsample_bytree': 0.4}

# %%
classifier  = xgboost.XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=0.4, gamma=0.1, gpu_id=-1,
              importance_type='gain', interaction_constraints='',
              learning_rate=0.3, max_delta_step=0, max_depth=15,
              min_child_weight=5, missing=None, monotone_constraints='()',
              n_estimators=200, n_jobs=4, num_parallel_tree=1, random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
classifier.fit(X_train_over, y_train_over)
# Out:
# [17:49:41] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.4, gamma=0.1, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.3, max_delta_step=0, max_depth=15,
#               min_child_weight=5, missing=None, monotone_constraints='()',
#               n_estimators=200, n_jobs=4, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred = classifier.predict(X_test)

# %%
#for i in range(len(y_pred)):
#    if y_pred[i] < 0.45:
#        y_pred[i] = 0
#    else:
#        y_pred[i] = 1
        
        
#y_pred = y_pred.astype(np.int)
    

import numpy
unique, counts = numpy.unique(y_pred, return_counts = True)
dict(zip(unique, counts))
# Out:
# {0: 22777, 1: 5223}

# %%
pred=pd.DataFrame(y_pred)
sub_df=pd.read_csv('../input/simple-datasets/Test Data.csv')
results=pd.concat([sub_df['id'],pred],axis=1)
results.columns=['id','risk_flag']
results.to_csv('oversampling_hyper_xgb_new.csv',index=False)
